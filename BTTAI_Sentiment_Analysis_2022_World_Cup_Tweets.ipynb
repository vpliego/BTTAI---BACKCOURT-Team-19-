# %%
import pandas as pd
df = pd.read_csv('fifa_world_cup_2022_tweets.csv')

# %%
df.shape
# Out:
# (22524, 6)

# %%
df['Numerical Sentiment'] = 0

df.to_csv('updated_fifa_world_cup_2022-tweets.csv', index=False)

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'Date Created', 'Number of Likes', 'Source of Tweet', 'Tweet', 'Sentiment', 'Numerical Sentiment']

# %%
df.loc[df['Sentiment'] == 'positive', 'Numerical Sentiment'] = 1
df.loc[df['Sentiment'] == 'neutral', 'Numerical Sentiment'] = 0
df.loc[df['Sentiment'] == 'negative', 'Numerical Sentiment'] = -1

df.to_csv('updated_fifa_world_cup_2022-tweets.csv', index=False)

# %%
df.head(15)
# Out:
#     Unnamed: 0               Date Created  Number of Likes  \
# 0            0  2022-11-20 23:59:21+00:00                4
# 1            1  2022-11-20 23:59:01+00:00                3
# 2            2  2022-11-20 23:58:41+00:00                1
# 3            3  2022-11-20 23:58:33+00:00                1
# 4            4  2022-11-20 23:58:28+00:00                0
# 5            5  2022-11-20 23:57:32+00:00                0
# 6            6  2022-11-20 23:57:06+00:00                0
# 7            7  2022-11-20 23:57:05+00:00                0
# 8            8  2022-11-20 23:56:10+00:00                1
# 9            9  2022-11-20 23:56:08+00:00                0
# 10          10  2022-11-20 23:56:05+00:00                1
# 11          11  2022-11-20 23:54:44+00:00                0
# 12          12  2022-11-20 23:54:31+00:00                0
# 13          13  2022-11-20 23:54:12+00:00                5
# 14          14  2022-11-20 23:53:52+00:00                0
#
# ...

# %%
average_numerical_sentiment = df['Numerical Sentiment'].mean()
print(average_numerical_sentiment)
# Out:
# 0.12009412182560825

# %%
df.shape
# Out:
# (22524, 7)

# %%
import pandas as pd

missing_values = df.isnull().sum()
missing_values
# Out:
# Unnamed: 0             0
# Date Created           0
# Number of Likes        0
# Source of Tweet        0
# Tweet                  0
# Sentiment              0
# Numerical Sentiment    0
# dtype: int64
